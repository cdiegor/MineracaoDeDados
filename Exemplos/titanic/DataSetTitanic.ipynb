# %% [markdown]
# # Importando as bibliotecas necessárias

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Pré-processamento

# %%
data = pd.read_csv('titanic.csv')

# %%
data.info()

# %%
data = data.drop(['Name', 'PassengerId', 'Ticket', 'Cabin'], axis='columns')

# %%
from sklearn.preprocessing import LabelEncoder

data = data.dropna() # Exclui as linhas possuem valores NA

data['Age'] = data['Age'].astype(int) # Transformar o tipo da coluna Age para inteiro
le = LabelEncoder()
data['Sex'] = le.fit_transform(data['Sex'])
data['Embarked'] = le.fit_transform(data['Embarked'])
data
# Out:
# <ipython-input-24-718ea5dca2c2>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Age'] = data['Age'].astype(int) # Transformar o tipo da coluna Age para inteiro
# <ipython-input-24-718ea5dca2c2>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Sex'] = le.fit_transform(data['Sex'])
# <ipython-input-24-718ea5dca2c2>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Embarked'] = le.fit_transform(data['Embarked'])
#      Survived  Pclass  Sex  Age  SibSp  Parch     Fare  Embarked
# 0           0       3    1   22      1      0   7.2500         2
# 1           1       1    0   38      1      0  71.2833         0
# 2           1       3    0   26      0      0   7.9250         2
# 3           1       1    0   35      1      0  53.1000         2
# 4           0       3    1   35      0      0   8.0500         2
# ..        ...     ...  ...  ...    ...    ...      ...       ...
# 885         0       3    0   39      0      5  29.1250         1
# 886         0       2    1   27      0      0  13.0000         2
# 887         1       1    0   19      0      0  30.0000         2
# 889         1       1    1   26      0      0  30.0000         0
# 890         0       3    1   32      0      0   7.7500         1
#
# [712 rows x 8 columns]

# %%
dum = pd.get_dummies(data['Embarked']) # Dividindo a coluna 'Embarked' em 3 novas colunas
data = pd.concat([data,dum], axis=1) # Colocando as novas colunas no DataFrame
data = data.drop('Embarked', axis='columns') # Dropando a antiga coluna 'Embarked'

data = data.rename(columns={2: 'Southampton', 0:'Cherbourg', 1:'Queenstown'}) # Renomeando as colunas

# %%
data
# Out:
#      Survived  Pclass  Sex  Age  SibSp  Parch     Fare  Cherbourg  Queenstown  \
# 0           0       3    1   22      1      0   7.2500      False       False
# 1           1       1    0   38      1      0  71.2833       True       False
# 2           1       3    0   26      0      0   7.9250      False       False
# 3           1       1    0   35      1      0  53.1000      False       False
# 4           0       3    1   35      0      0   8.0500      False       False
# ..        ...     ...  ...  ...    ...    ...      ...        ...         ...
# 885         0       3    0   39      0      5  29.1250      False        True
# 886         0       2    1   27      0      0  13.0000      False       False
# 887         1       1    0   19      0      0  30.0000      False       False
# 889         1       1    1   26      0      0  30.0000       True       False
# 890         0       3    1   32      0      0   7.7500      False        True
#
#      Southampton
# 0           True
# 1          False
# 2           True
# 3           True
# 4           True
# ..           ...
# 885        False
# 886         True
# 887         True
# 889        False
# 890        False
#
# [712 rows x 10 columns]

# %%
dum2 = pd.get_dummies(data['Pclass']) # Dividindo a coluna 'Pclass' em 3 novas colunas
data = pd.concat([data,dum2], axis=1) # Colocando novas colunas no DataFrame
data = data.drop('Pclass', axis='columns') # Dropando a antiga coluna 'Pclass'
data = data.rename(columns={3:'Class3a', 2:'Class2a', 1:'Class1a'}) # Renomeando as colunas

# %%
data.info() # Domínio dos atributos
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 712 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Survived     712 non-null    int64
#  1   Sex          712 non-null    int64
#  2   Age          712 non-null    int64
#  3   SibSp        712 non-null    int64
#  4   Parch        712 non-null    int64
#  5   Fare         712 non-null    float64
#  6   Cherbourg    712 non-null    bool
#  7   Queenstown   712 non-null    bool
#  8   Southampton  712 non-null    bool
#  9   Class1a      712 non-null    bool
#  10  Class2a      712 non-null    bool
#  11  Class3a      712 non-null    bool
# dtypes: bool(6), float64(1), int64(5)
# memory usage: 43.1 KB

# %%
data.describe()
# Out:
#          Survived         Sex         Age       SibSp       Parch        Fare
# count  712.000000  712.000000  712.000000  712.000000  712.000000  712.000000
# mean     0.404494    0.636236   29.622191    0.514045    0.432584   34.567251
# std      0.491139    0.481420   14.502891    0.930692    0.854181   52.938648
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      0.000000    0.000000   20.000000    0.000000    0.000000    8.050000
# 50%      0.000000    1.000000   28.000000    0.000000    0.000000   15.645850
# 75%      1.000000    1.000000   38.000000    1.000000    1.000000   33.000000
# max      1.000000    1.000000   80.000000    5.000000    6.000000  512.329200

# %% [markdown]
# # Histograma dos atributos

# %% [markdown]
# # Dividindo entre conjunto de treinando e teste

# %%
y = data.iloc[:,0].values
x = data.iloc[:,1:].values
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.25, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# # Criando um classificador usando Árvore de Decisão

# %%
from sklearn.tree import DecisionTreeClassifier
classifier_Ad = DecisionTreeClassifier(criterion = 'entropy', random_state = 0)
classifier_Ad.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
predictions = classifier_Ad.predict(X_test)

# %% [markdown]
# # Matriz de Confusão da Árvore de Decisão

# %%
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score, f1_score, recall_score, precision_score

print("Accuracy: ", accuracy_score(y_test,predictions))
print(classification_report(y_test,predictions))
print(confusion_matrix(y_test,predictions))
# Out:
# Accuracy:  0.7471910112359551
#               precision    recall  f1-score   support
#
#            0       0.82      0.72      0.77       104
#            1       0.67      0.78      0.72        74
#
#     accuracy                           0.75       178
#    macro avg       0.75      0.75      0.74       178
# weighted avg       0.76      0.75      0.75       178
#
# [[75 29]
#  [16 58]]

# %% [markdown]
# # Criando um classificador usando Regressão Logística

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression(random_state = 0)
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0)

# %%
y_pred = classifier.predict(X_test)

# %% [markdown]
# # Matriz de Confusão da Regressão Logística

# %%
print("Accuracy: ", accuracy_score(y_test,y_pred))
print(classification_report(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
# Accuracy:  0.7752808988764045
#               precision    recall  f1-score   support
#
#            0       0.79      0.84      0.81       104
#            1       0.75      0.69      0.72        74
#
#     accuracy                           0.78       178
#    macro avg       0.77      0.76      0.77       178
# weighted avg       0.77      0.78      0.77       178
#
# [[87 17]
#  [23 51]]
