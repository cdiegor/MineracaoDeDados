# %% [markdown]
# # Redes neurais artificiais

# %% [markdown]
# ### Importando as bibliotecas

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# %%
tf.__version__

# %% [markdown]
# ## Part 1 - Pré processamento de dados

# %% [markdown]
# ### Importando o conjunto de dados

# %%
dataset = pd.read_csv('Churn_Modelling.csv')
X = dataset.iloc[:, 3:-1].values
y = dataset.iloc[:, -1].values

# %%
print(X)

# %%
print(y)

# %% [markdown]
# ### Codificando dados categóricos

# %% [markdown]
# Codificando a coluna 'Gender'

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
X[:, 2] = le.fit_transform(X[:, 2])

# %%
print(X)

# %% [markdown]
# Codificando a coluna 'Geography' com OneHotEncoder

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
ct = ColumnTransformer(transformers=[('encoder', OneHotEncoder(), [1])], remainder='passthrough')
X = np.array(ct.fit_transform(X))

# %%
print(X)

# %% [markdown]
# ### Dividindo o conjunto de dados em treinamento e teste

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %% [markdown]
# ### Escala de atributos

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %% [markdown]
# ## Parte 2 - Construindo a rede neural

# %% [markdown]
# ### Inicializando a rede neural

# %%
ann = tf.keras.models.Sequential()

# %% [markdown]
# ### Adicionando a camada de entrada e a primeira camada oculta

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %% [markdown]
# ### Adding the second hidden layer

# %%
ann.add(tf.keras.layers.Dense(units=6, activation='relu'))

# %% [markdown]
# ### Adicionando a camada de saída

# %%
ann.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# ## Parte 3 - Treinando a rede neural artificial

# %% [markdown]
# ### Compilando a rede neural

# %%
ann.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %% [markdown]
# ### Treinando a rede neural no conjunto de treinamento

# %%
ann.fit(X_train, y_train, batch_size = 32, epochs = 100)

# %% [markdown]
# ## Parte 4 - Fazendo as predições e avaliando o modelo

# %% [markdown]
# ### Prevendo uma única observação

# %% [markdown]
# **Utilizar a rede neural para prever o seguinte caso.**
#
# Geography: France
# Credit Score: 600
# Gender: Male
# Age: 40 years old
# Tenure: 3 years
# Balance: \$ 60000
# Number of Products: 2
# Does this customer have a credit card ? Yes
# Is this customer an Active Member? Yes
# Estimated Salary: \$ 50000
#
#
# **_Devemos dizer adeus ao cliente?_**

# %%
print(ann.predict(sc.transform([[1, 0, 0, 600, 1, 40, 3, 60000, 2, 1, 1, 50000]])) > 0.5)

# %% [markdown]
# ### Prevendo o resultado no conjunto de teste

# %%
y_pred = ann.predict(X_test)
y_pred = (y_pred > 0.5)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))

# %% [markdown]
# ### Fazendo a matriz de confusão

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
cm = confusion_matrix(y_test, y_pred)
print(cm)
accuracy_score(y_test, y_pred)
